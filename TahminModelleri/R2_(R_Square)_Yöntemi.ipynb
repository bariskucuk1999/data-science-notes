# %% [markdown]
# <a href="https://colab.research.google.com/github/bariskucuk1999/data-science-notes/blob/main/R2_(R_Square)_Y%C3%B6ntemi.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.tree import DecisionTreeRegressor
veriler=pd.read_csv("maaslar.txt")
x=veriler.iloc[:,1:2] #eğitim seviyesi
y=veriler.iloc[:,2:] #maas
X=x.values #data frame bu örnekte sklearn'de sıkıntı çıkardığı için numpy array dönüşümü
Y=y.values
regressor_dt = DecisionTreeRegressor(random_state=0)
regressor_dt.fit(X,Y)
Z = X + 0.5
K = X - 0.4
from sklearn.ensemble import RandomForestRegressor
rf_reg=RandomForestRegressor(n_estimators=10,random_state=0)
rf_reg.fit(X,Y.ravel())

#1 çıkması çok iyi tahmin, 0 çıkması kötü tahmin, negatif çıkması çok kötü tahmin
#n--->kaç tane eleman olduğu p--->kaç tane değişken aldığımızdır(1. denklemde 2 değişken, 2. denklemde 3 değişken)
from sklearn.metrics import r2_score
r2_score(Y,rf_reg.predict(X)) #r2_score(y_true,y_pred)
#çıkan sonuç random forest R2 değeri
# Out:
# 0.9704434230386582

# %%
r2_score(Y,regressor_dt.predict(X))
#çıkan sonuç decision tree R2 değeri
# Out:
# 1.0
